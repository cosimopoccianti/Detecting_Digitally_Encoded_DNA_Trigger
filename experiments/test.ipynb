# %%
from utils import join_datasets

# %%
full, clean, trojan = join_datasets(dataset='greedy_ecoli', dataset_number=10,encryption_key=0,fragment_len=5,retention_pos=5)
# Out:
# Succesfully loaded 20000 samples, 10000 clean and 10000 infected

# %%
clean
# Out:
# ['...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
#  '...',
# ...

# %%
with open("output.txt", "w") as f:
    for s in trojan:
        f.write(s + "\n")
